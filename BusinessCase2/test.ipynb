# %%
from utils.show_results import show_all
show_all()
# Out:
# 16:27:40  INFO
# ...
#   Running: xgboost
# ...
# 16:27:41  INFO      Running utils.xgboost_shap...
# 16:27:41  INFO      Loading data from c:\Users\giuli\Repositories\fintech-group-work\BusinessCase2\Data\Dataset2_Needs.xls
# 16:27:41  INFO      Loaded: shape=(5000, 9)
# 16:27:41  INFO      Target: IncomeInvestment
# 16:27:42  INFO        [F_B] CV  F1: 0.694 ± 0.020
# 16:27:42  INFO        [F_B] Brier: 0.1855 → 0.1682 (pre→post calibration)
# 16:27:42  INFO        [F_B] Test F1 (thr=0.5): 0.633
# 16:27:42  INFO      PR threshold: 0.302 → P=0.758 R=0.562 F1=0.646
# 16:27:42  INFO        Computing SHAP values...
# 16:27:44  INFO        [F_E] Test F1: 0.635  (ΔF_B−F_E = -0.002)
# 16:27:44  INFO      Saved: c:\Users\giuli\Repositories\fintech-group-work\BusinessCase2\data\pickled_files\xgboost_shap\incomeinvestment.joblib
# 16:27:44  INFO      Target: AccumulationInvestment
# 16:27:45  INFO        [F_B] CV  F1: 0.782 ± 0.016
# ...

# %% [markdown]
# for each of these results, write a paragraph of conclusions about how the model is performing
#
#
#
# ================================================================  XGBoost  |  IncomeInvestment================================================================  Metric            CV Mean±Std    Test@0.5  ------------------------------------------  accuracy        0.781 ± 0.012       0.776  precision       0.749 ± 0.029       0.854  recall          0.649 ± 0.033       0.503  f1              0.694 ± 0.020       0.633  PR-curve threshold = 0.302  (Precision≥0.75 constraint)                Precision     Recall         F1  At threshold      0.758      0.562      0.646  Brier score: 0.1855 (pre-cal) → 0.1682 (post-cal)  [baseline 0.25]  Ablation — F1 CV mean:    F_E: 0.689 ± 0.022    F_B: 0.694 ± 0.020    ΔF1 (F_E − F_B) = -0.005
#
#
#
# ================================================================
#
#   XGBoost  |  AccumulationInvestment
#
# ================================================================
#
#
#
#   Metric            CV Mean±Std    Test@0.5
#
#   ------------------------------------------
#
#   accuracy        0.787 ± 0.014       0.783
#
#   precision       0.823 ± 0.015       0.844
#
#   recall          0.745 ± 0.029       0.708
#
#   f1              0.782 ± 0.016       0.770
#
#
#
#   PR-curve threshold = 0.410  (Precision≥0.75 constraint)
#
#                 Precision     Recall         F1
#
#   At threshold      0.808      0.772      0.790
#
#
#
#   Brier score: 0.1640 (pre-cal) → 0.1510 (post-cal)  [baseline 0.25]
#
#
#
#   Ablation — F1 CV mean:
#
#     F_E: 0.769 ± 0.017
#
#     F_B: 0.782 ± 0.016
#
#     ΔF1 (F_E − F_B) = -0.013
#
#
#
# ================================================================  LogisticRegression  |  IncomeInvestment================================================================  Metric            CV Mean±Std    Test@0.5  ------------------------------------------  accuracy        0.743 ± 0.023       0.706  precision       0.661 ± 0.029       0.618  recall          0.679 ± 0.040       0.612  f1              0.669 ± 0.031       0.615  PR-curve threshold = 0.594  (Precision≥0.75 constraint)                Precision     Recall         F1  At threshold      0.750      0.523      0.617  Brier score: 0.1998  [baseline 0.25]  Ablation — F1 CV mean:    F_E: 0.669 ± 0.031    F_B: 0.650 ± 0.029    ΔF1 (F_E − F_B) = +0.019
#
#
#
# ================================================================
#
#   LogisticRegression  |  AccumulationInvestment
#
# ================================================================
#
#
#
#   Metric            CV Mean±Std    Test@0.5
#
#   ------------------------------------------
#
#   accuracy        0.665 ± 0.023       0.690
#
#   precision       0.659 ± 0.023       0.678
#
#   recall          0.724 ± 0.028       0.752
#
#   f1              0.689 ± 0.021       0.713
#
#
#
#   PR-curve threshold = 0.637  (Precision≥0.75 constraint)
#
#                 Precision     Recall         F1
#
#   At threshold      0.752      0.407      0.528
#
#
#
#   Brier score: 0.2226  [baseline 0.25]
#
#
#
#   Ablation — F1 CV mean:
#
#     F_E: 0.689 ± 0.021
#
#     F_B: 0.689 ± 0.023
#
#     ΔF1 (F_E − F_B) = +0.000
#
#
#
# ================================================================  GaussianNB  |  IncomeInvestment================================================================  Metric            CV Mean±Std    Test@0.5  ------------------------------------------  accuracy        0.748 ± 0.023       0.709  precision       0.692 ± 0.036       0.640  recall          0.619 ± 0.049       0.552  f1              0.652 ± 0.035       0.593  PR-curve threshold = 0.706  (Precision≥0.75 constraint)                Precision     Recall         F1  At threshold      0.751      0.393      0.516  Brier score: 0.2108  [baseline 0.25]
#
#
#
# ================================================================
#
#   GaussianNB  |  AccumulationInvestment
#
# ================================================================
#
#
#
#   Metric            CV Mean±Std    Test@0.5
#
#   ------------------------------------------
#
#   accuracy        0.611 ± 0.024       0.601
#
#   precision       0.603 ± 0.023       0.589
#
#   recall          0.717 ± 0.018       0.737
#
#   f1              0.655 ± 0.017       0.655
#
#
#
#   PR-curve threshold = 0.809  (Precision≥0.75 constraint)
#
#                 Precision     Recall         F1
#
#   At threshold      0.754      0.084      0.151
#
#
#
#   Brier score: 0.2436  [baseline 0.25]
#
#
#
# ================================================================  RandomForest  |  IncomeInvestment================================================================  Metric            CV Mean±Std    Test@0.5  ------------------------------------------  accuracy        0.811 ± 0.014       0.776  precision       0.848 ± 0.031       0.839  recall          0.619 ± 0.037       0.516  f1              0.715 ± 0.025       0.639  PR-curve threshold = 0.553  (Precision≥0.75 constraint)                Precision     Recall         F1  At threshold      0.868      0.513      0.645  Brier score: 0.1683 (pre-cal) → 0.1673 (post-cal)  [baseline 0.25]  Ablation — F1 CV mean:    F_E: 0.715 ± 0.025    F_B: 0.716 ± 0.028    ΔF1 (F_E − F_B) = -0.001
#
#
#
# ================================================================
#
#   RandomForest  |  AccumulationInvestment
#
# ================================================================
#
#
#
#   Metric            CV Mean±Std    Test@0.5
#
#   ------------------------------------------
#
#   accuracy        0.795 ± 0.015       0.778
#
#   precision       0.841 ± 0.018       0.836
#
#   recall          0.742 ± 0.027       0.706
#
#   f1              0.788 ± 0.018       0.765
#
#
#
#   PR-curve threshold = 0.362  (Precision≥0.75 constraint)
#
#                 Precision     Recall         F1
#
#   At threshold      0.784      0.786      0.785
#
#
#
#   Brier score: 0.1534 (pre-cal) → 0.1503 (post-cal)  [baseline 0.25]
#
#
#
#   Ablation — F1 CV mean:
#
#     F_E: 0.788 ± 0.018
#
#     F_B: 0.786 ± 0.019
#
#     ΔF1 (F_E − F_B) = +0.003
#
#
#
# ================================================================  MLP  |  IncomeInvestment================================================================  Metric            CV Mean±Std    Test@0.5  ------------------------------------------  accuracy        0.792 ± 0.014       0.757  precision       0.824 ± 0.029       0.766  recall          0.583 ± 0.041       0.529  f1              0.682 ± 0.028       0.626  Ablation — F1 CV mean:    F_E: 0.682 ± 0.028    F_B: 0.671 ± 0.032    ΔF1 (F_E − F_B) = +0.011
#
#
#
# ================================================================
#
#   MLP  |  AccumulationInvestment
#
# ================================================================
#
#
#
#   Metric            CV Mean±Std    Test@0.5
#
#   ------------------------------------------
#
#   accuracy        0.790 ± 0.023       0.771
#
#   precision       0.864 ± 0.038       0.809
#
#   recall          0.702 ± 0.028       0.725
#
#   f1              0.774 ± 0.023       0.765
#
#
#
#   Ablation — F1 CV mean:
#
#     F_E: 0.774 ± 0.023
#
#     F_B: 0.769 ± 0.017
#
#     ΔF1 (F_E − F_B) = +0.005
#
#
#
# ================================================================
#
#   ClassifierChain(XGBoost)  |  IncomeInvestment
#
# ================================================================
#
#
#
#   Metric            CV Mean±Std    Test@0.5
#
#   ------------------------------------------
#
#   accuracy        0.778 ± 0.022       0.796
#
#   precision       0.768 ± 0.030       0.803
#
#   recall          0.594 ± 0.041       0.656
#
#   f1              0.669 ± 0.029       0.722
#
#
#
# ================================================================  SoftVotingEnsemble(LR+XGB+SVM)  |  IncomeInvestment================================================================  Metric            CV Mean±Std    Test@0.5  ------------------------------------------  accuracy        0.800 ± 0.015       0.767  precision       0.816 ± 0.028       0.792  recall          0.619 ± 0.040       0.534  f1              0.703 ± 0.028       0.638  PR-curve threshold = 0.472  (Precision≥0.75 constraint)                Precision     Recall         F1  At threshold      0.776      0.549      0.643  Brier score: 0.1740  [baseline 0.25]  Ablation — F1 CV mean:    F_E: 0.703 ± 0.028    F_B: 0.707 ± 0.029    ΔF1 (F_E − F_B) = -0.004
#
#
#
# ================================================================
#
#   SoftVotingEnsemble(LR+XGB+SVM)  |  AccumulationInvestment
#
# ================================================================
#
#
#
#   Metric            CV Mean±Std    Test@0.5
#
#   ------------------------------------------
#
#   accuracy        0.782 ± 0.017       0.763
#
#   precision       0.817 ± 0.021       0.777
#
#   recall          0.743 ± 0.021       0.754
#
#   f1              0.778 ± 0.017       0.766
#
#
#
#   PR-curve threshold = 0.462  (Precision≥0.75 constraint)
#
#                 Precision     Recall         F1
#
#   At threshold      0.754      0.795      0.774
#
#
#
#   Brier score: 0.1710  [baseline 0.25]
#
#
#
#   Ablation — F1 CV mean:
#
#     F_E: 0.778 ± 0.017
#
#     F_B: 0.765 ± 0.021
#
#     ΔF1 (F_E − F_B) = +0.013
#
#
#
# ================================================================  HardVotingEnsemble(LR+XGB+SVM)  |  IncomeInvestment================================================================  Metric            CV Mean±Std    Test@0.5  ------------------------------------------  accuracy        0.789 ± 0.016       0.756  precision       0.773 ± 0.022       0.738  recall          0.638 ± 0.039       0.565  f1              0.698 ± 0.028       0.640  Ablation — F1 CV mean:    F_E: 0.698 ± 0.028    F_B: 0.691 ± 0.027    ΔF1 (F_E − F_B) = +0.007
#
#
#
# ================================================================
#
#   HardVotingEnsemble(LR+XGB+SVM)  |  AccumulationInvestment
#
# ================================================================
#
#
#
#   Metric            CV Mean±Std    Test@0.5
#
#   ------------------------------------------
#
#   accuracy        0.765 ± 0.018       0.750
#
#   precision       0.794 ± 0.018       0.760
#
#   recall          0.731 ± 0.024       0.749
#
#   f1              0.761 ± 0.019       0.754
#
#
#
#   Ablation — F1 CV mean:
#
#     F_E: 0.761 ± 0.019
#
#     F_B: 0.730 ± 0.023
#
#     ΔF1 (F_E − F_B) = +0.031
